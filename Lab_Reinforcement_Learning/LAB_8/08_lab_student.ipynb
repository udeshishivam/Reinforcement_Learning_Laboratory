# %% [markdown]
# # EECS 598 Lab 8: Rapid Motor Adaptation (Phase 2)
#
# ![rma](https://www.therobotreport.com/wp-content/uploads/2021/07/legged-robot-adapts.jpg)

# %% [markdown]
# This notebook is worth **80 points**. Your score will be calculated as `score = min(score, 80)`.
# Questions and implementations are marked with relevent `#TODO(student)` markers.
#
# Before starting the assignment, please put your name and UMID in the following format:
#
# Firstname LASTNAME, #00000000 (ex. Drew SCHEFFER #31415926)

# %% [markdown]
# **YOUR ANSWER**
#
# SHIVAM UDESHI, #87841376

# %% [markdown]
# ## Setup

# %%
import sys, types, importlib

# Create a tiny fake 'imp' module exposing only 'reload'
_imp = types.ModuleType("imp")
_imp.reload = importlib.reload
sys.modules["imp"] = _imp

# load autoreload
# %load_ext autoreload
# %autoreload 2

# %%
print('Setting environment variable to use GPU rendering:')
# %env MUJOCO_GL=egl
# %env XLA_PYTHON_CLIENT_PREALLOCATE=false
# Out:
# Setting environment variable to use GPU rendering:
# env: MUJOCO_GL=egl
# env: XLA_PYTHON_CLIENT_PREALLOCATE=false

# %%
#@title Import packages for plotting and creating graphics
import time
import itertools
import numpy as np
from typing import Callable, NamedTuple, Optional, Union, List

# Graphics and plotting.
print('Installing mediapy:')
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy
import mediapy as media
import matplotlib.pyplot as plt

# More legible printing from numpy.
np.set_printoptions(precision=3, suppress=True, linewidth=100)
# Out:
# Installing mediapy:

# %% [markdown]
# ### Google Colab Setup

# %% [markdown]
# Next, we'll run a few commands to set up the environment on Google Colab. If you are running this notebook locally you can skip this section

# %% [markdown]
# Run the following to mount this notebook to your Google Drive. Follow the link and sign into the Google account following the prompts. Use the same Google account that you used to store this notebook.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Now update the path below to point to the folder in your Google Drive where you uploaded this notebook. If everything worked correctly you should see the following filenames at least: [`08_lab_student.ipynb`, `EECS598RSLRLBraxWrapper.py`, `rma_go1_locomote.py`, `rma_rsl_rl/`]

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded project 2
# Example: If you create a 2025FA folder and put all the files under Lab6, then '2025FA/Lab6'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '2025FA/Lab8'

GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '/content/drive/MyDrive/CSE598/lab8-rma-phase2/lab8-rma-phase2'
GOOGLE_DRIVE_PATH_LAB8 = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)

print(os.listdir(GOOGLE_DRIVE_PATH_LAB8))

# Add to path and change directory for good measure
sys.path.append(GOOGLE_DRIVE_PATH_LAB8)
os.chdir(GOOGLE_DRIVE_PATH_LAB8)
# Out:
# ['.DS_Store', 'scene_mjx_feetonly_rough_terrain.xml', 'rma_rsl_rl', 'teacher_checkpoints', '__pycache__', 'rma_go1_locomote.py', 'EECS598RSLRLBraxWrapper.py', 'teacher_rollout.mp4', '08_lab_student.ipynb']

# %%
from google.colab import files

import distutils.util
import os
import subprocess
if subprocess.run('nvidia-smi').returncode:
  raise RuntimeError(
      'Cannot communicate with GPU. '
      'Make sure you are using a GPU Colab runtime. '
      'Go to the Runtime menu and select Choose runtime type.')

# Add an ICD config so that glvnd can pick up the Nvidia EGL driver.
# This is usually installed as part of an Nvidia driver package, but the Colab
# kernel doesn't install its driver via APT, and as a result the ICD is missing.
# (https://github.com/NVIDIA/libglvnd/blob/master/src/EGL/icd_enumeration.md)
NVIDIA_ICD_CONFIG_PATH = '/usr/share/glvnd/egl_vendor.d/10_nvidia.json'
if not os.path.exists(NVIDIA_ICD_CONFIG_PATH):
  with open(NVIDIA_ICD_CONFIG_PATH, 'w') as f:
    f.write("""{
    "file_format_version" : "1.0.0",
    "ICD" : {
        "library_path" : "libEGL_nvidia.so.0"
    }
}
""")

# %% [markdown]
# ### Install customized rsl_rl library

# %%
# %cd rma_rsl_rl
# Out:
# /content/drive/MyDrive/CSE598/lab8-rma-phase2/lab8-rma-phase2/rma_rsl_rl

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/CSE598/lab8-rma-phase2/lab8-rma-phase2/rma_rsl_rl
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from rsl_rl==1.0.2) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from rsl_rl==1.0.2) (0.23.0+cu126)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.12/dist-packages (from rsl_rl==1.0.2) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.4.0->rsl_rl==1.0.2) (3.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.5.0->rsl_rl==1.0.2) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.4.0->rsl_rl==1.0.2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.4.0->rsl_rl==1.0.2) (3.0.3)
# Installing collected packages: rsl_rl
#   Attempting uninstall: rsl_rl
#     Found existing installation: rsl_rl 1.0.2
#     Uninstalling rsl_rl-1.0.2:
#       Successfully uninstalled rsl_rl-1.0.2
#   Running setup.py develop for rsl_rl
# Successfully installed rsl_rl-1.0.2

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/CSE598/lab8-rma-phase2/lab8-rma-phase2

# %% [markdown]
# If the below, throws an error, you likely have to restart your runtime.

# %%
import rsl_rl
from rsl_rl.runners import OnPolicyRunnerRMA
from rsl_rl.runners import OnPolicyRunnerDagger

# %% [markdown]
# ## Mujoco, JAX, MJX, BRAX, and Playground Setup & Imports

# %%
# !pip install mujoco
# !pip install mujoco_mjx
# !pip install brax
# !pip install noise

# TODO(student): If you're running this locally, make sure to install cuda enabled jax via something like:
# !pip install "jax[cuda12]"
# Out:
# Requirement already satisfied: mujoco in /usr/local/lib/python3.12/dist-packages (3.3.7)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco) (1.13.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from mujoco) (2.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mujoco) (2.0.2)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco) (3.1.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (3.23.0)
# Requirement already satisfied: mujoco_mjx in /usr/local/lib/python3.12/dist-packages (3.3.7)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco_mjx) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco_mjx) (1.13.0)
# Requirement already satisfied: jax in /usr/local/lib/python3.12/dist-packages (from mujoco_mjx) (0.7.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.12/dist-packages (from mujoco_mjx) (0.7.2)
# Requirement already satisfied: mujoco>=3.3.7.dev0 in /usr/local/lib/python3.12/dist-packages (from mujoco_mjx) (3.3.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mujoco_mjx) (1.16.2)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.12/dist-packages (from mujoco_mjx) (4.9.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from mujoco>=3.3.7.dev0->mujoco_mjx) (2.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mujoco>=3.3.7.dev0->mujoco_mjx) (2.0.2)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco>=3.3.7.dev0->mujoco_mjx) (3.1.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco_mjx) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco_mjx) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco_mjx) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco_mjx) (3.23.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax->mujoco_mjx) (0.5.3)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax->mujoco_mjx) (3.4.0)
# Requirement already satisfied: brax in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from brax) (1.4.0)
# Requirement already satisfied: etils in /usr/local/lib/python3.12/dist-packages (from brax) (1.13.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.12/dist-packages (from brax) (3.1.2)
# Requirement already satisfied: flask-cors in /usr/local/lib/python3.12/dist-packages (from brax) (6.0.1)
# Requirement already satisfied: flax in /usr/local/lib/python3.12/dist-packages (from brax) (0.10.7)
# Requirement already satisfied: jax>=0.4.6 in /usr/local/lib/python3.12/dist-packages (from brax) (0.7.2)
# Requirement already satisfied: jaxlib>=0.4.6 in /usr/local/lib/python3.12/dist-packages (from brax) (0.7.2)
# Requirement already satisfied: jaxopt in /usr/local/lib/python3.12/dist-packages (from brax) (0.8.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from brax) (3.1.6)
# Requirement already satisfied: ml-collections in /usr/local/lib/python3.12/dist-packages (from brax) (1.1.0)
# Requirement already satisfied: mujoco in /usr/local/lib/python3.12/dist-packages (from brax) (3.3.7)
# Requirement already satisfied: mujoco-mjx in /usr/local/lib/python3.12/dist-packages (from brax) (3.3.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from brax) (2.0.2)
# Requirement already satisfied: optax in /usr/local/lib/python3.12/dist-packages (from brax) (0.2.6)
# Requirement already satisfied: orbax-checkpoint>=0.11.22 in /usr/local/lib/python3.12/dist-packages (from brax) (0.11.25)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from brax) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from brax) (1.16.2)
# Requirement already satisfied: tensorboardx in /usr/local/lib/python3.12/dist-packages (from brax) (2.6.4)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.12/dist-packages (from brax) (4.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from brax) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.4.6->brax) (0.5.3)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax>=0.4.6->brax) (3.4.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax) (1.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax) (6.0.3)
# Requirement already satisfied: tensorstore>=0.1.71 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax) (0.1.78)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax) (1.6.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax) (4.14.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax) (3.20.2)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask->brax) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask->brax) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask->brax) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask->brax) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask->brax) (3.1.3)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.12/dist-packages (from flax->brax) (13.9.4)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax->brax) (0.1.10)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from mujoco->brax) (2.10.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco->brax) (3.1.10)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.12/dist-packages (from optax->brax) (0.1.90)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboardx->brax) (25.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->brax) (75.2.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->brax) (0.12.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax->brax) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax->brax) (2.19.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint>=0.11.22->brax) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint>=0.11.22->brax) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint>=0.11.22->brax) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->brax) (0.1.2)
# Requirement already satisfied: noise in /usr/local/lib/python3.12/dist-packages (1.2.2)

# %%
# !pip install playground
# !pip install wandb
# !pip install tensorboard
# Out:
# Requirement already satisfied: playground in /usr/local/lib/python3.12/dist-packages (0.0.5)
# Requirement already satisfied: brax>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from playground) (0.13.0)
# Requirement already satisfied: etils in /usr/local/lib/python3.12/dist-packages (from playground) (1.13.0)
# Requirement already satisfied: flax in /usr/local/lib/python3.12/dist-packages (from playground) (0.10.7)
# Requirement already satisfied: jax in /usr/local/lib/python3.12/dist-packages (from playground) (0.7.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from playground) (5.4.0)
# Requirement already satisfied: ml-collections in /usr/local/lib/python3.12/dist-packages (from playground) (1.1.0)
# Requirement already satisfied: mujoco-mjx>=3.2.7 in /usr/local/lib/python3.12/dist-packages (from playground) (3.3.7)
# Requirement already satisfied: mujoco>=3.2.7 in /usr/local/lib/python3.12/dist-packages (from playground) (3.3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from playground) (4.67.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (1.4.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (3.1.2)
# Requirement already satisfied: flask-cors in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (6.0.1)
# Requirement already satisfied: jaxlib>=0.4.6 in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (0.7.2)
# Requirement already satisfied: jaxopt in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (0.8.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (2.0.2)
# Requirement already satisfied: optax in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (0.2.6)
# Requirement already satisfied: orbax-checkpoint>=0.11.22 in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (0.11.25)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (1.16.2)
# Requirement already satisfied: tensorboardx in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (2.6.4)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (4.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from brax>=0.12.1->playground) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax->playground) (0.5.3)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax->playground) (3.4.0)
# Requirement already satisfied: glfw in /usr/local/lib/python3.12/dist-packages (from mujoco>=3.2.7->playground) (2.10.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco>=3.2.7->playground) (3.1.10)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from flax->playground) (1.1.2)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.12/dist-packages (from flax->playground) (0.1.78)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.12/dist-packages (from flax->playground) (13.9.4)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from flax->playground) (6.0.3)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax->playground) (0.1.10)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground) (1.6.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground) (4.14.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint>=0.11.22->brax>=0.12.1->playground) (3.20.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax->playground) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax->playground) (2.19.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=3.2.7->playground) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=3.2.7->playground) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco>=3.2.7->playground) (3.23.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask->brax>=0.12.1->playground) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask->brax>=0.12.1->playground) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask->brax>=0.12.1->playground) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask->brax>=0.12.1->playground) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask->brax>=0.12.1->playground) (3.1.3)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.12/dist-packages (from optax->brax>=0.12.1->playground) (0.1.90)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboardx->brax>=0.12.1->playground) (25.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->brax>=0.12.1->playground) (75.2.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->brax>=0.12.1->playground) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->playground) (0.1.2)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.22.2)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.45)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.11.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.42.1)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (3.9)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboard) (25.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)

# %%
import os

try:
  print('Checking that the installation succeeded:')
  import mujoco
  mujoco.MjModel.from_xml_string('<mujoco/>')
except Exception as e:
  raise e from RuntimeError(
      'Something went wrong during installation. Check the shell output above '
      'for more information.\n'
      'If using a hosted Colab runtime, make sure you enable GPU acceleration '
      'by going to the Runtime menu and selecting "Choose runtime type".')

print('Installation successful.')

# Tell XLA to use Triton GEMM, this improves steps/sec by ~30% on some GPUs
xla_flags = os.environ.get('XLA_FLAGS', '')
xla_flags += ' --xla_gpu_triton_gemm_any=True'
os.environ['XLA_FLAGS'] = xla_flags
# Out:
# Checking that the installation succeeded:
# Installation successful.

# %% [markdown]
# Ensure that the output of the following cell is `[CudaDevice(id=0)]`

# %%
import jax
print(jax.devices())
# Out:
# [CudaDevice(id=0)]

# %%
#@title Import MuJoCo, MJX, and Brax
from datetime import datetime
from etils import epath
import functools
from IPython.display import HTML
from typing import Any, Dict, Sequence, Tuple, Union
import os
from ml_collections import config_dict


import jax
from jax import numpy as jp
import numpy as np
from flax.training import orbax_utils
from flax import struct
from matplotlib import pyplot as plt
import mediapy as media
from orbax import checkpoint as ocp

import mujoco
from mujoco import mjx

from brax import base
from brax import envs
from brax import math
from brax.base import Base, Motion, Transform
from brax.base import State as PipelineState
from brax.envs.base import Env, PipelineEnv, State
from brax.mjx.base import State as MjxState
from brax.training.agents.ppo import train as ppo
from brax.training.agents.ppo import networks as ppo_networks
from brax.io import html, mjcf, model
# Out:
# Failed to import warp: No module named 'warp'
# Failed to import mujoco_warp: No module named 'warp'

# %%
import os

xla_flags = os.environ.get("XLA_FLAGS", "")
xla_flags += " --xla_gpu_triton_gemm_any=True"
os.environ["XLA_FLAGS"] = xla_flags
os.environ["MUJOCO_GL"] = "egl"

from datetime import datetime
import json

from absl import app
from absl import flags
from absl import logging
import jax
import mediapy as media
from ml_collections import config_dict
import mujoco
import torch

import mujoco_playground
from mujoco_playground import registry
from mujoco_playground import wrapper_torch
from mujoco_playground import wrapper
from mujoco_playground.config import locomotion_params
from mujoco_playground.config import manipulation_params
from mujoco_playground.config import dm_control_suite_params

# Suppress logs if you want
logging.set_verbosity(logging.WARNING)

# %% [markdown]
# # Recap of Rapid Motor Adaptation (RMA)
#
# ![here](https://ar5iv.labs.arxiv.org/html/2107.04034/assets/x1.png)
#
# Today, we'll continue to investigate one popular Sim2Real reinforcement learning paradigm: learning (and distilling) from privileged information available in simulation. One popular implementation of this idea is [Rapid Motor Adaption for Legged Robots (RMA)](https://ashish-kmr.github.io/rma-legged-robots/). In this formulation, training robotic locomotion policies are split up into two main phases, as shown in the figure above.
#
# In **phase 1**, a motor policy, $\pi$, is trained that takes as input the state, $x_t$, the previous action $a_t$ and a learned environment latent vector $z_t$ that encodes features of the environment that may be relevant for adapting the robot's policy, but may not be directly observable when the robot is deployed in the real world (such as friction, center of mass position, etc). In this sense, you can think of $z_t$ as conditioning the policy. At this stage, however, the policy would not be able to be applied directly on a real robot, because the policy requires access to privilegded state to generate $z_t$.
#
# In **phase 2**, the motor policy is frozen (no longer updated), and an adaptation module is trained to *approximate* the environment feature $z_t$ using *only* the robot's extended state history $x_{1...T}, a_{1...T}$. Crucially, since we're training both phases in simulation, we can rollout the phase 1 privileged information encoder to get "ground truth" $z_t$ labels for each timestep. So, we can do simple supervised learning to estimate $\hat{z}_t$ from state history!
#
# In today's lab, we'll focus on implementing the knowledge distillation in **phase 2** of RMA. If you need a refresher, I suggest that you look through [the paper](https://ashish-kmr.github.io/rma-legged-robots/rma-locomotion-final.pdf).

# %% [markdown]
# `TODO(student):` Explain in your own words why it's important that both Phase 1 and Phase 2 are trained in simulation. **(10 points)**.
#
# **[Answer Here]**
#
# Both phases of RMA are trained in simulation because the simulator provides access to privileged information—like friction, mass, or terrain properties—that the real robot cannot directly measure. In Phase 1, this allows the motor policy to learn how to adapt its behavior using these hidden environment details. Then, in Phase 2, we can use simulation to generate ground truth labels for the latent environment vector, letting the adaptation module learn to predict it from past observations. Training in simulation is also safer and lets the robot experience many diverse environments before being deployed in the real world.

# %% [markdown]
# # Loading the Privileged "Teacher" Policy (Trained using Phase 1)
# First, we'll load and visualize our "teacher policy" that was trained using Phase 1 of RMA. Compared to the last lab, this policy was trained using rough terrain, penalty reward curriculum (as described in the paper), more privileged information, and was trained for more iterations. Feel free to checkout the `rma_go1_locomote.py` environment to see the updated implementation.
#
# Note, to get a more optimal teacher policy you'd likely have to do much more tedious reward tuning. But this should work for this lab!

# %% [markdown]
# ### Load policy from checkpoint

# %%
from glob import glob
from rma_go1_locomote import go1_rma_default_config, rma_domain_randomize, LocomotionRMAEnv

_SEED=10
device="cuda:0"

# Get the model checkpoint
ckpt_num = 6000
model_path = f"./teacher_checkpoints/model_{ckpt_num}.pt"

teacher_render_trajectory = []
def teacher_render_callback(_, state):
    teacher_render_trajectory.append(state)

# Create the parent env
randomizer = rma_domain_randomize
env_cfg = go1_rma_default_config()
raw_eval_env = LocomotionRMAEnv(config=env_cfg, task="rough_terrain")
from EECS598RSLRLBraxWrapper import EECS598RSLRLBraxWrapper
brax_eval_env = EECS598RSLRLBraxWrapper(
    raw_eval_env,
    num_actors=1,
    seed=_SEED,
    episode_length=env_cfg.episode_length,
    action_repeat=1,
    randomization_fn=randomizer,
    render_callback=teacher_render_callback,
)

#Load the trained, priveleged RMA policy
train_cfg = locomotion_params.rsl_rl_config("")
train_cfg.runner_class_name = "OnPolicyRunnerRMA"
train_cfg_dict = train_cfg.to_dict()
train_cfg_dict["policy_class_name"] = "ActorCriticLatent"# "ActorCriticLatent"
train_cfg_dict["algorithm_class_name"] = "PPO_priv"

# Get the Parent runner and policy
runner = OnPolicyRunnerRMA(brax_eval_env, train_cfg_dict, device=device)
runner.load(path=model_path)
policy = runner.get_inference_policy(device=device)
# Out:
# obs_shape: {'privileged_state': (17,), 'state': (51,)}
# Asymmetric observation space
# JITing reset and step
# Done JITing reset and step
# ActorCriticLatent.__init__ got unexpected arguments, which will be ignored: ['class_name']
# Actor MLP: MLPEncode(
#   (activation_fn): ELU(alpha=1.0)
#   (output_activation_fn): Tanh()
#   (prop_encoder): Sequential(
#     (0): Linear(in_features=17, out_features=256, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=128, out_features=8, bias=True)
#     (5): ELU(alpha=1.0)
#   )
#   (action_mlp): Sequential(
#     (0): Linear(in_features=59, out_features=512, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ELU(alpha=1.0)
#     (6): Linear(in_features=128, out_features=12, bias=True)
#     (7): Tanh()
#   )
# )
# Critic MLP: MLPEncode(
#   (activation_fn): ELU(alpha=1.0)
#   (prop_encoder): Sequential(
#     (0): Linear(in_features=17, out_features=256, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=128, out_features=8, bias=True)
#     (5): ELU(alpha=1.0)
#   )
#   (action_mlp): Sequential(
#     (0): Linear(in_features=59, out_features=512, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ELU(alpha=1.0)
#     (6): Linear(in_features=128, out_features=1, bias=True)
#   )
# )
# This is the algorithm class:  PPO_priv
# PPO_priv.__init__ got unexpected arguments, which will be ignored: ['class_name']
# Priveleged PPO is loaded
# Runner loaded

# %% [markdown]
# ### Perform a rollout
# `TODO(student):` Fill in the TODO below to generate the teacher policy rollout. **(20 points)**

# %%
obs = brax_eval_env.get_observations()
privileged_obs = brax_eval_env.get_privileged_observations()

actor_critic = runner.alg.actor_critic

from tqdm import tqdm
with torch.inference_mode():
    for _ in tqdm(range(env_cfg.episode_length)):
        obs_tensor = torch.tensor(obs, dtype=torch.float32, device=device)
        priv_tensor = torch.tensor(privileged_obs, dtype=torch.float32, device=device)

        # 5. Concatenate inputs (this is what the model expects!)
        full_obs = torch.cat([obs_tensor, priv_tensor], dim=-1)

        # 6. Forward pass through actor network
        with torch.inference_mode():
            actions = actor_critic.actor.architecture(full_obs)

            z_t = actor_critic.actor.architecture.only_latent(full_obs)
        obs, privileged_obs, rewards, dones, infos = brax_eval_env.step(actions)

        if dones.any():
            break

        brax_eval_env.render()

print("The final z_t is ", z_t)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]/tmp/ipython-input-478609876.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   obs_tensor = torch.tensor(obs, dtype=torch.float32, device=device)
# /tmp/ipython-input-478609876.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   priv_tensor = torch.tensor(privileged_obs, dtype=torch.float32, device=device)
# 100%|█████████▉| 999/1000 [01:03<00:00, 15.72it/s]
# The final z_t is  tensor([[-0.9978, -0.3001, -1.0000, -1.0000, -0.1475, -1.0000, -0.9947, -1.0000]],
#        device='cuda:0')

# %% [markdown]
# ### Render the video

# %%
# Render the video
print("Rendering a video")
scene_option = mujoco.MjvOption()
scene_option.geomgroup[2] = True
scene_option.geomgroup[3] = False
scene_option.flags[mujoco.mjtVisFlag.mjVIS_CONTACTPOINT] = True
scene_option.flags[mujoco.mjtVisFlag.mjVIS_PERTFORCE] = True
scene_option.flags[mujoco.mjtVisFlag.mjVIS_CONTACTFORCE] = False


render_every = 2


# If your environment is wrapped multiple times, adjust as needed:
base_env = brax_eval_env.env.env.env  # or brax_env.env.env.env
fps = 1.0 / base_env.dt / render_every
traj = teacher_render_trajectory[::render_every]
frames = raw_eval_env.render(
    traj,
    camera="track",
    height=480,
    width=640,
    scene_option=scene_option,
)

file_name = f"teacher_rollout.mp4"
media.write_video(file_name, frames, fps=fps)
print(f"Rollout video saved as '{file_name}'.")
media.show_video(frames, fps=fps)
# Out:
# /content/drive/MyDrive/CSE598/lab8-rma-phase2/lab8-rma-phase2/rma_rsl_rl/rsl_rl/algorithms/dagger.py:48: SyntaxWarning: invalid escape sequence '\h'
#   '''Given proprioceptive history, return \hat{z_t}'''
# Rendering a video
# 100%|██████████| 500/500 [00:02<00:00, 203.27it/s]
# Rollout video saved as 'teacher_rollout.mp4'.
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="640" height="480" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# # RMA Phase 2: Implement Teacher-Student Distillation
# Awesome! Now that the privilieged teacher policy is trained, we can use it's priviliged environment encoder to obtain a "ground-truth" $z_t$ label for each timestep in the simulation. In the Phase 2 stage of RMA, all we'll be doing is building an encoder that tries to regress to the $z_t$ label using information that the robot will have access to in the real world (i.e. its proprioceptive history).
#
# To do this, we'll again again be building off of the familiar [RSL_RL](https://github.com/leggedrobotics/rsl_rl) framework discussed in previous labs, extending its training loop to incorporate these new elements. Crucially, though, we're not doing any RL in phase 2, just supervised regression.
#
# Our adapted RSL_RL library resides in the `rma_rsl_rl` folder. There are a few important files to look at:
# - `./rsl_rl/runners/on_policy_runner_dagger.py` This file contains the main training and logging loop and is responsible for rolling out and training the policy in simulation. I recommend you take a moment to read through this file.
# - `./rsl_rl/algorithms/dagger.py` This file connects the *expert* policy and the *student* policy, stores the computed ($z_t$, prop_history) and performs regression steps.
# - `./rsl_rl/modules/adaptation.py` This file defines the "adaptation module" that produces estimates of $\hat{z}_t$ given history $(x_{t-50:t-1}, a_{{t-50:t-1}})$
#
# Please briefly take a look at all of these files to get a sense of the structure.
#
# In this lab, the only file that you have to do implementation in is `./rsl_rl/algorithms/dagger.py`. You'll train the adaptation encoder by acquiring $z_t$ and $\hat{z}_t$ and perform regression steps.

# %% [markdown]
# `TODO(student):` Fill in the TODOs in `./rsl_rl/algorithms/dagger.py` to train the adaptation encoder.
#
# 1. Implement the TODOs in `DaggerAgent.get_student_latent()`, `DaggerAgent.get_expert_latent()`. **(20 points)**
#
# 2. Implement the TODOs in `DaggerTrainer.observe()`, `DaggerTrainer.step()`, `DaggerTrainer.update()`. **(20 points)**

# %% [markdown]
# # Run Phase 2 Training
# Train the Phase 2 RMA policy! It shouldn't take too long to train.

# %% [markdown]
# ### Get the Configs

# %%
_EXP_NAME = "RMA_DAGGER"
_SUFFIX = None
_USE_WANDB = False
_PLAY_ONLY = False
_NUM_ENVS = 4096
_LOAD_RUN_NAME = None
_CHECKPOINT_NUM = -1

def _init_logging_and_exp():
    # Experiment name
    now = datetime.now()
    timestamp = now.strftime("%Y%m%d-%H%M%S")
    exp_name = f"{_EXP_NAME}-{timestamp}"
    exp_name += f"-{_SUFFIX}"
    print(f"Experiment name: {exp_name}")

    # Logging directory
    logdir = os.path.abspath(os.path.join("logs", exp_name))
    os.makedirs(logdir, exist_ok=True)
    print(f"Logs are being stored in: {logdir}")

    # Checkpoint directory
    ckpt_path = os.path.join(logdir, "checkpoints")
    os.makedirs(ckpt_path, exist_ok=True)
    print(f"Checkpoint path: {ckpt_path}")

    # Save environment config to JSON
    with open(
        os.path.join(ckpt_path, "config.json"), "w", encoding="utf-8"
    ) as fp:
        json.dump(env_cfg.to_dict(), fp, indent=4)

    return exp_name, logdir, ckpt_path

def _get_training_config_dict(exp_name):
    train_cfg = locomotion_params.rsl_rl_config("") # get the default
    train_cfg.seed = _SEED
    train_cfg.run_name = exp_name
    train_cfg.resume = _LOAD_RUN_NAME is not None
    train_cfg.load_run = _LOAD_RUN_NAME if _LOAD_RUN_NAME else "-1"
    train_cfg.checkpoint = _CHECKPOINT_NUM
    train_cfg.runner_class_name = "OnPolicyRunnerDagger"

    train_cfg_dict = train_cfg.to_dict()


    train_cfg_dict["expert_policy_name"] = "DaggerExpert"
    train_cfg_dict["student_policy_class"] = "DaggerAgent"
    train_cfg_dict["history_len"] = 50

    return train_cfg_dict
# Out:
# /content/drive/MyDrive/CSE598/lab8-rma-phase2/lab8-rma-phase2/rma_rsl_rl/rsl_rl/algorithms/dagger.py:48: SyntaxWarning: invalid escape sequence '\h'
#   '''Given proprioceptive history, return \hat{z_t}'''

# %% [markdown]
# ### Setup the Student Runner

# %%
from EECS598RSLRLBraxWrapper import EECS598RSLRLBraxWrapper
from rsl_rl.runners import OnPolicyRunnerDagger

# Initialize the base env
randomizer = rma_domain_randomize
env_cfg = go1_rma_default_config()
raw_env = LocomotionRMAEnv(task="flat_terrain", config=env_cfg) #task in {flat_terrain, rough_terrain}
brax_env = EECS598RSLRLBraxWrapper(
    raw_env,
    _NUM_ENVS,
    _SEED,
    env_cfg.episode_length,
    1,
    randomization_fn=randomizer,
)


# Init the logging dirs
exp_name, logdir, ckpt_path = _init_logging_and_exp()
print(f"Experiment {exp_name}:  storing checkpoints in {ckpt_path}")

# Setup the Dagger Runner
print("\n\nSetting up the Dagger Runner")
train_cfg_dict = _get_training_config_dict(exp_name)
expert_policy = runner.alg.actor_critic.actor.architecture
dagger_runner = OnPolicyRunnerDagger(expert_policy, env=brax_env, train_cfg=train_cfg_dict, log_dir=logdir, device=device)
# Out:
# obs_shape: {'privileged_state': (17,), 'state': (51,)}
# Asymmetric observation space
# JITing reset and step
# Done JITing reset and step
# Experiment name: RMA_DAGGER-20251023-223916-None
# Logs are being stored in: /content/drive/MyDrive/CSE598/lab8-rma-phase2/lab8-rma-phase2/logs/RMA_DAGGER-20251023-223916-None
# Checkpoint path: /content/drive/MyDrive/CSE598/lab8-rma-phase2/lab8-rma-phase2/logs/RMA_DAGGER-20251023-223916-None/checkpoints
# Experiment RMA_DAGGER-20251023-223916-None:  storing checkpoints in /content/drive/MyDrive/CSE598/lab8-rma-phase2/lab8-rma-phase2/logs/RMA_DAGGER-20251023-223916-None/checkpoints
#
#
# Setting up the Dagger Runner
# Dagger Runner Loaded

# %% [markdown]
# ### Train the Student Policy

# %%
dagger_runner.learn(
    num_learning_iterations=100,
    init_at_random_ep_len=False,
)
print("training finished")
# Out:
# ################################################################################
#                         Learning iteration 0/100
#
#                        Computation: 1017 steps/s (collection: 93.958s, learning 2.685s)
#                   Prop latent loss: 0.6121
#                        Mean reward: -2.11
#                Mean episode length: 14.77
# --------------------------------------------------------------------------------
#                    Total timesteps: 98304
#                     Iteration time: 96.64s
#                         Total time: 96.64s
#                                ETA: 9664.3s
#
# ################################################################################
#                         Learning iteration 1/100
#
#                        Computation: 34769 steps/s (collection: 0.987s, learning 1.840s)
#                   Prop latent loss: 0.1622
#                        Mean reward: -2.27
#                Mean episode length: 14.91
# --------------------------------------------------------------------------------
#                    Total timesteps: 196608
#                     Iteration time: 2.83s
#                         Total time: 99.47s
#                                ETA: 4923.8s
#
# ################################################################################
#                         Learning iteration 2/100
#
#                        Computation: 33598 steps/s (collection: 1.092s, learning 1.834s)
#                   Prop latent loss: 0.0471
#                        Mean reward: -2.03
#                Mean episode length: 15.92
# --------------------------------------------------------------------------------
#                    Total timesteps: 294912
#                     Iteration time: 2.93s
#                         Total time: 102.40s
#                                ETA: 3345.0s
#
# ################################################################################
#                         Learning iteration 3/100
#
#                        Computation: 35429 steps/s (collection: 0.943s, learning 1.832s)
#                   Prop latent loss: 0.0397
#                        Mean reward: -1.99
#                Mean episode length: 16.45
# --------------------------------------------------------------------------------
#                    Total timesteps: 393216
#                     Iteration time: 2.77s
#                         Total time: 105.17s
#                                ETA: 2550.4s
#
# ################################################################################
#                         Learning iteration 4/100
#
#                        Computation: 34849 steps/s (collection: 0.983s, learning 1.837s)
#                   Prop latent loss: 0.0391
#                        Mean reward: -2.00
#                Mean episode length: 17.19
# --------------------------------------------------------------------------------
#                    Total timesteps: 491520
#                     Iteration time: 2.82s
#                         Total time: 107.99s
#                                ETA: 2073.4s
#
# ################################################################################
#                         Learning iteration 5/100
#
#                        Computation: 35389 steps/s (collection: 0.937s, learning 1.841s)
#                   Prop latent loss: 0.0390
#                        Mean reward: -1.99
#                Mean episode length: 17.15
# --------------------------------------------------------------------------------
#                    Total timesteps: 589824
#                     Iteration time: 2.78s
#                         Total time: 110.77s
#                                ETA: 1753.9s
#
# ################################################################################
#                         Learning iteration 6/100
#
#                        Computation: 35064 steps/s (collection: 0.964s, learning 1.839s)
#                   Prop latent loss: 0.0390
#                        Mean reward: -1.98
#                Mean episode length: 17.16
# --------------------------------------------------------------------------------
#                    Total timesteps: 688128
#                     Iteration time: 2.80s
#                         Total time: 113.57s
#                                ETA: 1525.1s
#
# ################################################################################
#                         Learning iteration 7/100
#
#                        Computation: 33659 steps/s (collection: 1.074s, learning 1.847s)
#                   Prop latent loss: 0.0389
#                        Mean reward: -1.98
#                Mean episode length: 17.12
# --------------------------------------------------------------------------------
#                    Total timesteps: 786432
#                     Iteration time: 2.92s
#                         Total time: 116.49s
#                                ETA: 1354.2s
#
# ################################################################################
#                         Learning iteration 8/100
#
#                        Computation: 34086 steps/s (collection: 1.039s, learning 1.845s)
#                   Prop latent loss: 0.0389
#                        Mean reward: -1.98
#                Mean episode length: 17.13
# --------------------------------------------------------------------------------
#                    Total timesteps: 884736
#                     Iteration time: 2.88s
#                         Total time: 119.38s
#                                ETA: 1220.3s
#
# ################################################################################
#                         Learning iteration 9/100
#
#                        Computation: 33727 steps/s (collection: 1.067s, learning 1.847s)
#                   Prop latent loss: 0.0389
#                        Mean reward: -1.94
#                Mean episode length: 18.40
# --------------------------------------------------------------------------------
#                    Total timesteps: 983040
#                     Iteration time: 2.91s
#                         Total time: 122.29s
#                                ETA: 1112.9s
#
# ################################################################################
#                        Learning iteration 10/100
#
#                        Computation: 35277 steps/s (collection: 0.940s, learning 1.847s)
#                   Prop latent loss: 0.0389
#                        Mean reward: -1.94
#                Mean episode length: 18.40
# --------------------------------------------------------------------------------
#                    Total timesteps: 1081344
#                     Iteration time: 2.79s
#                         Total time: 125.08s
#                                ETA: 1023.4s
#
# ################################################################################
#                        Learning iteration 11/100
#
#                        Computation: 32282 steps/s (collection: 1.193s, learning 1.853s)
#                   Prop latent loss: 0.0389
#                        Mean reward: -1.94
#                Mean episode length: 18.40
# --------------------------------------------------------------------------------
#                    Total timesteps: 1179648
#                     Iteration time: 3.05s
#                         Total time: 128.12s
#                                ETA: 950.3s
#
# ################################################################################
#                        Learning iteration 12/100
#
#                        Computation: 35190 steps/s (collection: 0.943s, learning 1.850s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.94
#                Mean episode length: 18.40
# --------------------------------------------------------------------------------
#                    Total timesteps: 1277952
#                     Iteration time: 2.79s
#                         Total time: 130.92s
#                                ETA: 886.2s
#
# ################################################################################
#                        Learning iteration 13/100
#
#                        Computation: 35190 steps/s (collection: 0.942s, learning 1.852s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.89
#                Mean episode length: 20.41
# --------------------------------------------------------------------------------
#                    Total timesteps: 1376256
#                     Iteration time: 2.79s
#                         Total time: 133.71s
#                                ETA: 830.9s
#
# ################################################################################
#                        Learning iteration 14/100
#
#                        Computation: 35147 steps/s (collection: 0.944s, learning 1.853s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.89
#                Mean episode length: 20.44
# --------------------------------------------------------------------------------
#                    Total timesteps: 1474560
#                     Iteration time: 2.80s
#                         Total time: 136.51s
#                                ETA: 782.6s
#
# ################################################################################
#                        Learning iteration 15/100
#
#                        Computation: 34696 steps/s (collection: 0.967s, learning 1.866s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.89
#                Mean episode length: 20.44
# --------------------------------------------------------------------------------
#                    Total timesteps: 1572864
#                     Iteration time: 2.83s
#                         Total time: 139.34s
#                                ETA: 740.3s
#
# ################################################################################
#                        Learning iteration 16/100
#
#                        Computation: 33595 steps/s (collection: 1.069s, learning 1.857s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.68
#                Mean episode length: 27.34
# --------------------------------------------------------------------------------
#                    Total timesteps: 1671168
#                     Iteration time: 2.93s
#                         Total time: 142.27s
#                                ETA: 703.0s
#
# ################################################################################
#                        Learning iteration 17/100
#
#                        Computation: 34647 steps/s (collection: 0.976s, learning 1.861s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.68
#                Mean episode length: 27.34
# --------------------------------------------------------------------------------
#                    Total timesteps: 1769472
#                     Iteration time: 2.84s
#                         Total time: 145.10s
#                                ETA: 669.1s
#
# ################################################################################
#                        Learning iteration 18/100
#
#                        Computation: 33216 steps/s (collection: 1.100s, learning 1.859s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.68
#                Mean episode length: 27.34
# --------------------------------------------------------------------------------
#                    Total timesteps: 1867776
#                     Iteration time: 2.96s
#                         Total time: 148.06s
#                                ETA: 639.0s
#
# ################################################################################
#                        Learning iteration 19/100
#
#                        Computation: 34991 steps/s (collection: 0.947s, learning 1.863s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.68
#                Mean episode length: 27.34
# --------------------------------------------------------------------------------
#                    Total timesteps: 1966080
#                     Iteration time: 2.81s
#                         Total time: 150.87s
#                                ETA: 611.0s
#
# ################################################################################
#                        Learning iteration 20/100
#
#                        Computation: 31905 steps/s (collection: 1.217s, learning 1.864s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.68
#                Mean episode length: 27.34
# --------------------------------------------------------------------------------
#                    Total timesteps: 2064384
#                     Iteration time: 3.08s
#                         Total time: 153.95s
#                                ETA: 586.5s
#
# ################################################################################
#                        Learning iteration 21/100
#
#                        Computation: 33114 steps/s (collection: 1.098s, learning 1.870s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.68
#                Mean episode length: 27.34
# --------------------------------------------------------------------------------
#                    Total timesteps: 2162688
#                     Iteration time: 2.97s
#                         Total time: 156.92s
#                                ETA: 563.5s
#
# ################################################################################
#                        Learning iteration 22/100
#
#                        Computation: 34932 steps/s (collection: 0.949s, learning 1.865s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 2260992
#                     Iteration time: 2.81s
#                         Total time: 159.74s
#                                ETA: 541.7s
#
# ################################################################################
#                        Learning iteration 23/100
#
#                        Computation: 34909 steps/s (collection: 0.951s, learning 1.865s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 2359296
#                     Iteration time: 2.82s
#                         Total time: 162.55s
#                                ETA: 521.5s
#
# ################################################################################
#                        Learning iteration 24/100
#
#                        Computation: 34914 steps/s (collection: 0.949s, learning 1.866s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 2457600
#                     Iteration time: 2.82s
#                         Total time: 165.37s
#                                ETA: 502.7s
#
# ################################################################################
#                        Learning iteration 25/100
#
#                        Computation: 33393 steps/s (collection: 1.063s, learning 1.881s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 2555904
#                     Iteration time: 2.94s
#                         Total time: 168.31s
#                                ETA: 485.5s
#
# ################################################################################
#                        Learning iteration 26/100
#
#                        Computation: 34841 steps/s (collection: 0.951s, learning 1.870s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 2654208
#                     Iteration time: 2.82s
#                         Total time: 171.13s
#                                ETA: 469.0s
#
# ################################################################################
#                        Learning iteration 27/100
#
#                        Computation: 34830 steps/s (collection: 0.950s, learning 1.872s)
#                   Prop latent loss: 0.0388
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 2752512
#                     Iteration time: 2.82s
#                         Total time: 173.96s
#                                ETA: 453.5s
#
# ################################################################################
#                        Learning iteration 28/100
#
#                        Computation: 34172 steps/s (collection: 1.001s, learning 1.875s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 2850816
#                     Iteration time: 2.88s
#                         Total time: 176.83s
#                                ETA: 439.0s
#
# ################################################################################
#                        Learning iteration 29/100
#
#                        Computation: 34524 steps/s (collection: 0.974s, learning 1.874s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 2949120
#                     Iteration time: 2.85s
#                         Total time: 179.68s
#                                ETA: 425.2s
#
# ################################################################################
#                        Learning iteration 30/100
#
#                        Computation: 31768 steps/s (collection: 1.215s, learning 1.880s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 3047424
#                     Iteration time: 3.09s
#                         Total time: 182.77s
#                                ETA: 412.7s
#
# ################################################################################
#                        Learning iteration 31/100
#
#                        Computation: 34801 steps/s (collection: 0.950s, learning 1.874s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 3145728
#                     Iteration time: 2.82s
#                         Total time: 185.60s
#                                ETA: 400.2s
#
# ################################################################################
#                        Learning iteration 32/100
#
#                        Computation: 34381 steps/s (collection: 0.981s, learning 1.878s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 3244032
#                     Iteration time: 2.86s
#                         Total time: 188.46s
#                                ETA: 388.3s
#
# ################################################################################
#                        Learning iteration 33/100
#
#                        Computation: 34676 steps/s (collection: 0.957s, learning 1.878s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 3342336
#                     Iteration time: 2.83s
#                         Total time: 191.29s
#                                ETA: 377.0s
#
# ################################################################################
#                        Learning iteration 34/100
#
#                        Computation: 34335 steps/s (collection: 0.985s, learning 1.878s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 3440640
#                     Iteration time: 2.86s
#                         Total time: 194.16s
#                                ETA: 366.1s
#
# ################################################################################
#                        Learning iteration 35/100
#
#                        Computation: 34664 steps/s (collection: 0.955s, learning 1.881s)
#                   Prop latent loss: 0.0386
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 3538944
#                     Iteration time: 2.84s
#                         Total time: 196.99s
#                                ETA: 355.7s
#
# ################################################################################
#                        Learning iteration 36/100
#
#                        Computation: 33802 steps/s (collection: 1.028s, learning 1.880s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 3637248
#                     Iteration time: 2.91s
#                         Total time: 199.90s
#                                ETA: 345.8s
#
# ################################################################################
#                        Learning iteration 37/100
#
#                        Computation: 34630 steps/s (collection: 0.956s, learning 1.882s)
#                   Prop latent loss: 0.0387
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 3735552
#                     Iteration time: 2.84s
#                         Total time: 202.74s
#                                ETA: 336.1s
#
# ################################################################################
#                        Learning iteration 38/100
#
#                        Computation: 34629 steps/s (collection: 0.954s, learning 1.884s)
#                   Prop latent loss: 0.0386
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 3833856
#                     Iteration time: 2.84s
#                         Total time: 205.58s
#                                ETA: 326.8s
#
# ################################################################################
#                        Learning iteration 39/100
#
#                        Computation: 34028 steps/s (collection: 1.004s, learning 1.885s)
#                   Prop latent loss: 0.0386
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 3932160
#                     Iteration time: 2.89s
#                         Total time: 208.47s
#                                ETA: 317.9s
#
# ################################################################################
#                        Learning iteration 40/100
#
#                        Computation: 34301 steps/s (collection: 0.978s, learning 1.888s)
#                   Prop latent loss: 0.0386
#                        Mean reward: -1.64
#                Mean episode length: 28.53
# --------------------------------------------------------------------------------
#                    Total timesteps: 4030464
#                     Iteration time: 2.87s
#                         Total time: 211.33s
#                                ETA: 309.3s
#
# ################################################################################
#                        Learning iteration 41/100
#
#                        Computation: 34174 steps/s (collection: 0.992s, learning 1.885s)
#                   Prop latent loss: 0.0520
#                        Mean reward: -25.76
#                Mean episode length: 1000.00
# --------------------------------------------------------------------------------
#                    Total timesteps: 4128768
#                     Iteration time: 2.88s
#                         Total time: 214.21s
#                                ETA: 300.9s
#
# ################################################################################
#                        Learning iteration 42/100
#
#                        Computation: 34454 steps/s (collection: 0.963s, learning 1.890s)
#                   Prop latent loss: 0.0406
#                        Mean reward: -24.39
#                Mean episode length: 980.63
# --------------------------------------------------------------------------------
#                    Total timesteps: 4227072
#                     Iteration time: 2.85s
#                         Total time: 217.06s
#                                ETA: 292.8s
#
# ################################################################################
#                        Learning iteration 43/100
#
#                        Computation: 34320 steps/s (collection: 0.975s, learning 1.890s)
#                   Prop latent loss: 0.0398
#                        Mean reward: -17.17
#                Mean episode length: 913.35
# --------------------------------------------------------------------------------
#                    Total timesteps: 4325376
#                     Iteration time: 2.86s
#                         Total time: 219.93s
#                                ETA: 284.9s
#
# ################################################################################
#                        Learning iteration 44/100
#
#                        Computation: 34540 steps/s (collection: 0.958s, learning 1.888s)
#                   Prop latent loss: 0.0384
#                        Mean reward: -9.53
#                Mean episode length: 895.05
# --------------------------------------------------------------------------------
#                    Total timesteps: 4423680
#                     Iteration time: 2.85s
#                         Total time: 222.77s
#                                ETA: 277.2s
#
# ################################################################################
#                        Learning iteration 45/100
#
#                        Computation: 34482 steps/s (collection: 0.957s, learning 1.894s)
#                   Prop latent loss: 0.0369
#                        Mean reward: -6.85
#                Mean episode length: 887.29
# --------------------------------------------------------------------------------
#                    Total timesteps: 4521984
#                     Iteration time: 2.85s
#                         Total time: 225.62s
#                                ETA: 269.8s
#
# ################################################################################
#                        Learning iteration 46/100
#
#                        Computation: 34502 steps/s (collection: 0.957s, learning 1.892s)
#                   Prop latent loss: 0.0355
#                        Mean reward: -5.08
#                Mean episode length: 677.93
# --------------------------------------------------------------------------------
#                    Total timesteps: 4620288
#                     Iteration time: 2.85s
#                         Total time: 228.47s
#                                ETA: 262.5s
#
# ################################################################################
#                        Learning iteration 47/100
#
#                        Computation: 34468 steps/s (collection: 0.959s, learning 1.893s)
#                   Prop latent loss: 0.0347
#                        Mean reward: 0.68
#                Mean episode length: 408.68
# --------------------------------------------------------------------------------
#                    Total timesteps: 4718592
#                     Iteration time: 2.85s
#                         Total time: 231.33s
#                                ETA: 255.4s
#
# ################################################################################
#                        Learning iteration 48/100
#
#                        Computation: 34170 steps/s (collection: 0.982s, learning 1.895s)
#                   Prop latent loss: 0.0338
#                        Mean reward: 2.37
#                Mean episode length: 316.15
# --------------------------------------------------------------------------------
#                    Total timesteps: 4816896
#                     Iteration time: 2.88s
#                         Total time: 234.20s
#                                ETA: 248.5s
#
# ################################################################################
#                        Learning iteration 49/100
#
#                        Computation: 34461 steps/s (collection: 0.959s, learning 1.893s)
#                   Prop latent loss: 0.0336
#                        Mean reward: 2.11
#                Mean episode length: 268.82
# --------------------------------------------------------------------------------
#                    Total timesteps: 4915200
#                     Iteration time: 2.85s
#                         Total time: 237.05s
#                                ETA: 241.8s
#
# ################################################################################
#                        Learning iteration 50/100
#
#                        Computation: 34494 steps/s (collection: 0.956s, learning 1.894s)
#                   Prop latent loss: 0.0327
#                        Mean reward: 1.37
#                Mean episode length: 211.23
# --------------------------------------------------------------------------------
#                    Total timesteps: 5013504
#                     Iteration time: 2.85s
#                         Total time: 239.90s
#                                ETA: 235.2s
#
# ################################################################################
#                        Learning iteration 51/100
#
#                        Computation: 34531 steps/s (collection: 0.953s, learning 1.894s)
#                   Prop latent loss: 0.0326
#                        Mean reward: 0.83
#                Mean episode length: 170.72
# --------------------------------------------------------------------------------
#                    Total timesteps: 5111808
#                     Iteration time: 2.85s
#                         Total time: 242.75s
#                                ETA: 228.7s
#
# ################################################################################
#                        Learning iteration 52/100
#
#                        Computation: 34142 steps/s (collection: 0.980s, learning 1.899s)
#                   Prop latent loss: 0.0324
#                        Mean reward: 1.04
#                Mean episode length: 178.55
# --------------------------------------------------------------------------------
#                    Total timesteps: 5210112
#                     Iteration time: 2.88s
#                         Total time: 245.63s
#                                ETA: 222.5s
#
# ################################################################################
#                        Learning iteration 53/100
#
#                        Computation: 34443 steps/s (collection: 0.959s, learning 1.896s)
#                   Prop latent loss: 0.0317
#                        Mean reward: 1.97
#                Mean episode length: 202.39
# --------------------------------------------------------------------------------
#                    Total timesteps: 5308416
#                     Iteration time: 2.85s
#                         Total time: 248.48s
#                                ETA: 216.3s
#
# ################################################################################
#                        Learning iteration 54/100
#
#                        Computation: 34411 steps/s (collection: 0.960s, learning 1.896s)
#                   Prop latent loss: 0.0318
#                        Mean reward: 2.58
#                Mean episode length: 217.59
# --------------------------------------------------------------------------------
#                    Total timesteps: 5406720
#                     Iteration time: 2.86s
#                         Total time: 251.34s
#                                ETA: 210.2s
#
# ################################################################################
#                        Learning iteration 55/100
#
#                        Computation: 34434 steps/s (collection: 0.959s, learning 1.896s)
#                   Prop latent loss: 0.0317
#                        Mean reward: 3.43
#                Mean episode length: 231.09
# --------------------------------------------------------------------------------
#                    Total timesteps: 5505024
#                     Iteration time: 2.85s
#                         Total time: 254.20s
#                                ETA: 204.3s
#
# ################################################################################
#                        Learning iteration 56/100
#
#                        Computation: 34429 steps/s (collection: 0.958s, learning 1.897s)
#                   Prop latent loss: 0.0313
#                        Mean reward: 3.76
#                Mean episode length: 239.71
# --------------------------------------------------------------------------------
#                    Total timesteps: 5603328
#                     Iteration time: 2.86s
#                         Total time: 257.05s
#                                ETA: 198.4s
#
# ################################################################################
#                        Learning iteration 57/100
#
#                        Computation: 34165 steps/s (collection: 0.980s, learning 1.897s)
#                   Prop latent loss: 0.0310
#                        Mean reward: 4.48
#                Mean episode length: 242.11
# --------------------------------------------------------------------------------
#                    Total timesteps: 5701632
#                     Iteration time: 2.88s
#                         Total time: 259.93s
#                                ETA: 192.7s
#
# ################################################################################
#                        Learning iteration 58/100
#
#                        Computation: 34326 steps/s (collection: 0.960s, learning 1.904s)
#                   Prop latent loss: 0.0309
#                        Mean reward: 4.69
#                Mean episode length: 247.35
# --------------------------------------------------------------------------------
#                    Total timesteps: 5799936
#                     Iteration time: 2.86s
#                         Total time: 262.79s
#                                ETA: 187.1s
#
# ################################################################################
#                        Learning iteration 59/100
#
#                        Computation: 33016 steps/s (collection: 1.076s, learning 1.902s)
#                   Prop latent loss: 0.0309
#                        Mean reward: 5.05
#                Mean episode length: 255.64
# --------------------------------------------------------------------------------
#                    Total timesteps: 5898240
#                     Iteration time: 2.98s
#                         Total time: 265.77s
#                                ETA: 181.6s
#
# ################################################################################
#                        Learning iteration 60/100
#
#                        Computation: 33609 steps/s (collection: 1.024s, learning 1.901s)
#                   Prop latent loss: 0.0305
#                        Mean reward: 5.65
#                Mean episode length: 272.41
# --------------------------------------------------------------------------------
#                    Total timesteps: 5996544
#                     Iteration time: 2.92s
#                         Total time: 268.69s
#                                ETA: 176.2s
#
# ################################################################################
#                        Learning iteration 61/100
#
#                        Computation: 34077 steps/s (collection: 0.986s, learning 1.898s)
#                   Prop latent loss: 0.0301
#                        Mean reward: 5.81
#                Mean episode length: 279.16
# --------------------------------------------------------------------------------
#                    Total timesteps: 6094848
#                     Iteration time: 2.88s
#                         Total time: 271.58s
#                                ETA: 170.8s
#
# ################################################################################
#                        Learning iteration 62/100
#
#                        Computation: 34233 steps/s (collection: 0.976s, learning 1.896s)
#                   Prop latent loss: 0.0299
#                        Mean reward: 5.60
#                Mean episode length: 276.95
# --------------------------------------------------------------------------------
#                    Total timesteps: 6193152
#                     Iteration time: 2.87s
#                         Total time: 274.45s
#                                ETA: 165.5s
#
# ################################################################################
#                        Learning iteration 63/100
#
#                        Computation: 34368 steps/s (collection: 0.961s, learning 1.899s)
#                   Prop latent loss: 0.0296
#                        Mean reward: 6.17
#                Mean episode length: 291.70
# --------------------------------------------------------------------------------
#                    Total timesteps: 6291456
#                     Iteration time: 2.86s
#                         Total time: 277.31s
#                                ETA: 160.3s
#
# ################################################################################
#                        Learning iteration 64/100
#
#                        Computation: 34340 steps/s (collection: 0.963s, learning 1.900s)
#                   Prop latent loss: 0.0294
#                        Mean reward: 6.57
#                Mean episode length: 301.31
# --------------------------------------------------------------------------------
#                    Total timesteps: 6389760
#                     Iteration time: 2.86s
#                         Total time: 280.17s
#                                ETA: 155.2s
#
# ################################################################################
#                        Learning iteration 65/100
#
#                        Computation: 34238 steps/s (collection: 0.968s, learning 1.903s)
#                   Prop latent loss: 0.0290
#                        Mean reward: 6.90
#                Mean episode length: 306.85
# --------------------------------------------------------------------------------
#                    Total timesteps: 6488064
#                     Iteration time: 2.87s
#                         Total time: 283.05s
#                                ETA: 150.1s
#
# ################################################################################
#                        Learning iteration 66/100
#
#                        Computation: 33916 steps/s (collection: 0.998s, learning 1.901s)
#                   Prop latent loss: 0.0287
#                        Mean reward: 7.24
#                Mean episode length: 302.36
# --------------------------------------------------------------------------------
#                    Total timesteps: 6586368
#                     Iteration time: 2.90s
#                         Total time: 285.94s
#                                ETA: 145.1s
#
# ################################################################################
#                        Learning iteration 67/100
#
#                        Computation: 34054 steps/s (collection: 0.986s, learning 1.901s)
#                   Prop latent loss: 0.0284
#                        Mean reward: 7.43
#                Mean episode length: 307.51
# --------------------------------------------------------------------------------
#                    Total timesteps: 6684672
#                     Iteration time: 2.89s
#                         Total time: 288.83s
#                                ETA: 140.2s
#
# ################################################################################
#                        Learning iteration 68/100
#
#                        Computation: 34338 steps/s (collection: 0.963s, learning 1.900s)
#                   Prop latent loss: 0.0279
#                        Mean reward: 7.96
#                Mean episode length: 320.05
# --------------------------------------------------------------------------------
#                    Total timesteps: 6782976
#                     Iteration time: 2.86s
#                         Total time: 291.69s
#                                ETA: 135.3s
#
# ################################################################################
#                        Learning iteration 69/100
#
#                        Computation: 34276 steps/s (collection: 0.965s, learning 1.903s)
#                   Prop latent loss: 0.0274
#                        Mean reward: 7.94
#                Mean episode length: 320.08
# --------------------------------------------------------------------------------
#                    Total timesteps: 6881280
#                     Iteration time: 2.87s
#                         Total time: 294.56s
#                                ETA: 130.4s
#
# ################################################################################
#                        Learning iteration 70/100
#
#                        Computation: 33914 steps/s (collection: 0.995s, learning 1.903s)
#                   Prop latent loss: 0.0269
#                        Mean reward: 7.57
#                Mean episode length: 311.68
# --------------------------------------------------------------------------------
#                    Total timesteps: 6979584
#                     Iteration time: 2.90s
#                         Total time: 297.46s
#                                ETA: 125.7s
#
# ################################################################################
#                        Learning iteration 71/100
#
#                        Computation: 34274 steps/s (collection: 0.968s, learning 1.901s)
#                   Prop latent loss: 0.0265
#                        Mean reward: 7.87
#                Mean episode length: 319.56
# --------------------------------------------------------------------------------
#                    Total timesteps: 7077888
#                     Iteration time: 2.87s
#                         Total time: 300.33s
#                                ETA: 121.0s
#
# ################################################################################
#                        Learning iteration 72/100
#
#                        Computation: 34187 steps/s (collection: 0.970s, learning 1.905s)
#                   Prop latent loss: 0.0266
#                        Mean reward: 8.23
#                Mean episode length: 329.91
# --------------------------------------------------------------------------------
#                    Total timesteps: 7176192
#                     Iteration time: 2.88s
#                         Total time: 303.20s
#                                ETA: 116.3s
#
# ################################################################################
#                        Learning iteration 73/100
#
#                        Computation: 34349 steps/s (collection: 0.960s, learning 1.901s)
#                   Prop latent loss: 0.0265
#                        Mean reward: 9.01
#                Mean episode length: 353.94
# --------------------------------------------------------------------------------
#                    Total timesteps: 7274496
#                     Iteration time: 2.86s
#                         Total time: 306.07s
#                                ETA: 111.7s
#
# ################################################################################
#                        Learning iteration 74/100
#
#                        Computation: 34173 steps/s (collection: 0.974s, learning 1.902s)
#                   Prop latent loss: 0.0259
#                        Mean reward: 10.04
#                Mean episode length: 378.67
# --------------------------------------------------------------------------------
#                    Total timesteps: 7372800
#                     Iteration time: 2.88s
#                         Total time: 308.94s
#                                ETA: 107.1s
#
# ################################################################################
#                        Learning iteration 75/100
#
#                        Computation: 33835 steps/s (collection: 1.003s, learning 1.903s)
#                   Prop latent loss: 0.0258
#                        Mean reward: 10.27
#                Mean episode length: 385.19
# --------------------------------------------------------------------------------
#                    Total timesteps: 7471104
#                     Iteration time: 2.91s
#                         Total time: 311.85s
#                                ETA: 102.6s
#
# ################################################################################
#                        Learning iteration 76/100
#
#                        Computation: 34226 steps/s (collection: 0.968s, learning 1.904s)
#                   Prop latent loss: 0.0255
#                        Mean reward: 10.83
#                Mean episode length: 397.75
# --------------------------------------------------------------------------------
#                    Total timesteps: 7569408
#                     Iteration time: 2.87s
#                         Total time: 314.72s
#                                ETA: 98.1s
#
# ################################################################################
#                        Learning iteration 77/100
#
#                        Computation: 34205 steps/s (collection: 0.971s, learning 1.903s)
#                   Prop latent loss: 0.0252
#                        Mean reward: 10.60
#                Mean episode length: 392.13
# --------------------------------------------------------------------------------
#                    Total timesteps: 7667712
#                     Iteration time: 2.87s
#                         Total time: 317.59s
#                                ETA: 93.6s
#
# ################################################################################
#                        Learning iteration 78/100
#
#                        Computation: 34131 steps/s (collection: 0.974s, learning 1.906s)
#                   Prop latent loss: 0.0250
#                        Mean reward: 10.80
#                Mean episode length: 397.11
# --------------------------------------------------------------------------------
#                    Total timesteps: 7766016
#                     Iteration time: 2.88s
#                         Total time: 320.47s
#                                ETA: 89.2s
#
# ################################################################################
#                        Learning iteration 79/100
#
#                        Computation: 33607 steps/s (collection: 1.015s, learning 1.910s)
#                   Prop latent loss: 0.0249
#                        Mean reward: 11.00
#                Mean episode length: 402.74
# --------------------------------------------------------------------------------
#                    Total timesteps: 7864320
#                     Iteration time: 2.93s
#                         Total time: 323.40s
#                                ETA: 84.9s
#
# ################################################################################
#                        Learning iteration 80/100
#
#                        Computation: 34162 steps/s (collection: 0.971s, learning 1.906s)
#                   Prop latent loss: 0.0247
#                        Mean reward: 11.96
#                Mean episode length: 426.74
# --------------------------------------------------------------------------------
#                    Total timesteps: 7962624
#                     Iteration time: 2.88s
#                         Total time: 326.28s
#                                ETA: 80.6s
#
# ################################################################################
#                        Learning iteration 81/100
#
#                        Computation: 34123 steps/s (collection: 0.974s, learning 1.907s)
#                   Prop latent loss: 0.0244
#                        Mean reward: 12.45
#                Mean episode length: 440.44
# --------------------------------------------------------------------------------
#                    Total timesteps: 8060928
#                     Iteration time: 2.88s
#                         Total time: 329.16s
#                                ETA: 76.3s
#
# ################################################################################
#                        Learning iteration 82/100
#
#                        Computation: 34171 steps/s (collection: 0.969s, learning 1.907s)
#                   Prop latent loss: 0.0244
#                        Mean reward: 13.25
#                Mean episode length: 462.67
# --------------------------------------------------------------------------------
#                    Total timesteps: 8159232
#                     Iteration time: 2.88s
#                         Total time: 332.03s
#                                ETA: 72.0s
#
# ################################################################################
#                        Learning iteration 83/100
#
#                        Computation: 33981 steps/s (collection: 0.987s, learning 1.906s)
#                   Prop latent loss: 0.0296
#                        Mean reward: 36.58
#                Mean episode length: 1000.00
# --------------------------------------------------------------------------------
#                    Total timesteps: 8257536
#                     Iteration time: 2.89s
#                         Total time: 334.93s
#                                ETA: 67.8s
#
# ################################################################################
#                        Learning iteration 84/100
#
#                        Computation: 29582 steps/s (collection: 1.415s, learning 1.908s)
#                   Prop latent loss: 0.0320
#                        Mean reward: 34.70
#                Mean episode length: 958.42
# --------------------------------------------------------------------------------
#                    Total timesteps: 8355840
#                     Iteration time: 3.32s
#                         Total time: 338.25s
#                                ETA: 63.7s
#
# ################################################################################
#                        Learning iteration 85/100
#
#                        Computation: 33569 steps/s (collection: 1.022s, learning 1.906s)
#                   Prop latent loss: 0.0286
#                        Mean reward: 32.48
#                Mean episode length: 934.79
# --------------------------------------------------------------------------------
#                    Total timesteps: 8454144
#                     Iteration time: 2.93s
#                         Total time: 341.18s
#                                ETA: 59.5s
#
# ################################################################################
#                        Learning iteration 86/100
#
#                        Computation: 33102 steps/s (collection: 1.063s, learning 1.907s)
#                   Prop latent loss: 0.0264
#                        Mean reward: 30.91
#                Mean episode length: 887.91
# --------------------------------------------------------------------------------
#                    Total timesteps: 8552448
#                     Iteration time: 2.97s
#                         Total time: 344.15s
#                                ETA: 55.4s
#
# ################################################################################
#                        Learning iteration 87/100
#
#                        Computation: 33464 steps/s (collection: 1.027s, learning 1.910s)
#                   Prop latent loss: 0.0260
#                        Mean reward: 25.62
#                Mean episode length: 764.81
# --------------------------------------------------------------------------------
#                    Total timesteps: 8650752
#                     Iteration time: 2.94s
#                         Total time: 347.09s
#                                ETA: 51.3s
#
# ################################################################################
#                        Learning iteration 88/100
#
#                        Computation: 33610 steps/s (collection: 1.008s, learning 1.917s)
#                   Prop latent loss: 0.0264
#                        Mean reward: 6.34
#                Mean episode length: 384.34
# --------------------------------------------------------------------------------
#                    Total timesteps: 8749056
#                     Iteration time: 2.92s
#                         Total time: 350.01s
#                                ETA: 47.2s
#
# ################################################################################
#                        Learning iteration 89/100
#
#                        Computation: 33947 steps/s (collection: 0.988s, learning 1.907s)
#                   Prop latent loss: 0.0245
#                        Mean reward: 4.10
#                Mean episode length: 376.11
# --------------------------------------------------------------------------------
#                    Total timesteps: 8847360
#                     Iteration time: 2.90s
#                         Total time: 352.91s
#                                ETA: 43.1s
#
# ################################################################################
#                        Learning iteration 90/100
#
#                        Computation: 34194 steps/s (collection: 0.965s, learning 1.910s)
#                   Prop latent loss: 0.0229
#                        Mean reward: 5.00
#                Mean episode length: 381.59
# --------------------------------------------------------------------------------
#                    Total timesteps: 8945664
#                     Iteration time: 2.87s
#                         Total time: 355.78s
#                                ETA: 39.1s
#
# ################################################################################
#                        Learning iteration 91/100
#
#                        Computation: 34184 steps/s (collection: 0.967s, learning 1.909s)
#                   Prop latent loss: 0.0221
#                        Mean reward: 6.56
#                Mean episode length: 432.05
# --------------------------------------------------------------------------------
#                    Total timesteps: 9043968
#                     Iteration time: 2.88s
#                         Total time: 358.66s
#                                ETA: 35.1s
#
# ################################################################################
#                        Learning iteration 92/100
#
#                        Computation: 34131 steps/s (collection: 0.972s, learning 1.908s)
#                   Prop latent loss: 0.0221
#                        Mean reward: 7.78
#                Mean episode length: 490.75
# --------------------------------------------------------------------------------
#                    Total timesteps: 9142272
#                     Iteration time: 2.88s
#                         Total time: 361.54s
#                                ETA: 31.1s
#
# ################################################################################
#                        Learning iteration 93/100
#
#                        Computation: 33901 steps/s (collection: 0.991s, learning 1.909s)
#                   Prop latent loss: 0.0221
#                        Mean reward: 7.06
#                Mean episode length: 467.79
# --------------------------------------------------------------------------------
#                    Total timesteps: 9240576
#                     Iteration time: 2.90s
#                         Total time: 364.44s
#                                ETA: 27.1s
#
# ################################################################################
#                        Learning iteration 94/100
#
#                        Computation: 34224 steps/s (collection: 0.962s, learning 1.911s)
#                   Prop latent loss: 0.0220
#                        Mean reward: 8.29
#                Mean episode length: 484.74
# --------------------------------------------------------------------------------
#                    Total timesteps: 9338880
#                     Iteration time: 2.87s
#                         Total time: 367.31s
#                                ETA: 23.2s
#
# ################################################################################
#                        Learning iteration 95/100
#
#                        Computation: 34248 steps/s (collection: 0.962s, learning 1.909s)
#                   Prop latent loss: 0.0219
#                        Mean reward: 9.23
#                Mean episode length: 511.34
# --------------------------------------------------------------------------------
#                    Total timesteps: 9437184
#                     Iteration time: 2.87s
#                         Total time: 370.18s
#                                ETA: 19.3s
#
# ################################################################################
#                        Learning iteration 96/100
#
#                        Computation: 34228 steps/s (collection: 0.964s, learning 1.908s)
#                   Prop latent loss: 0.0215
#                        Mean reward: 9.26
#                Mean episode length: 523.95
# --------------------------------------------------------------------------------
#                    Total timesteps: 9535488
#                     Iteration time: 2.87s
#                         Total time: 373.05s
#                                ETA: 15.4s
#
# ################################################################################
#                        Learning iteration 97/100
#
#                        Computation: 33881 steps/s (collection: 0.994s, learning 1.907s)
#                   Prop latent loss: 0.0213
#                        Mean reward: 9.75
#                Mean episode length: 539.59
# --------------------------------------------------------------------------------
#                    Total timesteps: 9633792
#                     Iteration time: 2.90s
#                         Total time: 375.95s
#                                ETA: 11.5s
#
# ################################################################################
#                        Learning iteration 98/100
#
#                        Computation: 34239 steps/s (collection: 0.964s, learning 1.908s)
#                   Prop latent loss: 0.0213
#                        Mean reward: 9.60
#                Mean episode length: 508.39
# --------------------------------------------------------------------------------
#                    Total timesteps: 9732096
#                     Iteration time: 2.87s
#                         Total time: 378.82s
#                                ETA: 7.7s
#
# ################################################################################
#                        Learning iteration 99/100
#
#                        Computation: 34186 steps/s (collection: 0.965s, learning 1.910s)
#                   Prop latent loss: 0.0211
#                        Mean reward: 10.69
#                Mean episode length: 503.17
# --------------------------------------------------------------------------------
#                    Total timesteps: 9830400
#                     Iteration time: 2.88s
#                         Total time: 381.70s
#                                ETA: 3.8s
#
# training finished

# %% [markdown]
# # Evaluate/Visualize the Student Policy

# %%
student_policy = dagger_runner.get_inference_policy(device=device)
raw_eval_env = LocomotionRMAEnv(task="rough_terrain", config=env_cfg) #task in {flat_terrain, rough_terrain}


render_trajectory = []
def render_callback(_, state):
    render_trajectory.append(state)

num_eval_envs = 1
from EECS598RSLRLBraxWrapper import EECS598RSLRLBraxWrapper
brax_eval_env = EECS598RSLRLBraxWrapper(
    raw_eval_env,
    1,
    _SEED+2,
    env_cfg.episode_length,
    1,
    render_callback=render_callback,
    randomization_fn=randomizer,
)
# Out:
# obs_shape: {'privileged_state': (17,), 'state': (51,)}
# Asymmetric observation space
# JITing reset and step
# Done JITing reset and step

# %% [markdown]
# ### Perform a rollout
# `TODO(student):` Perform a rollout using the student_policy. Make sure you correctly initialize and update the proprioceptive history **(20 points)**

# %%
render_trajectory = []

# TODO(student): Initialize the history buffer
history = torch.zeros((brax_eval_env.num_envs, dagger_runner.history_shape), dtype=torch.float, device=device)

obs = brax_eval_env.get_observations()


from tqdm import tqdm
with torch.inference_mode():
    for _ in tqdm(range(env_cfg.episode_length)):
        actions = dagger_runner.actor.get_student_action(obs, history) #TODO(student): use the student policy

        obs, privileged_obs, rewards, dones, infos = brax_eval_env.step(actions)

        brax_eval_env.render()

        # TODO(student): Update the rolling history
        # Make a copy of the current observation
        obs_clone = obs.clone()
        steps = brax_eval_env.num_obs
        new_history = torch.zeros_like(history)
        new_history[:, :-steps] = history[:, steps:]
        new_history[:, -steps:] = obs_clone
        history = new_history



        if dones.any():
            break
# Out:
# 100%|█████████▉| 999/1000 [01:03<00:00, 15.69it/s]

# %% [markdown]
# ### Render a Video

# %%
from IPython.display import Video
_CAMERA = None

# Render
scene_option = mujoco.MjvOption()
scene_option.geomgroup[2] = True
scene_option.geomgroup[3] = False
scene_option.flags[mujoco.mjtVisFlag.mjVIS_CONTACTPOINT] = True
scene_option.flags[mujoco.mjtVisFlag.mjVIS_TRANSPARENT] = False
scene_option.flags[mujoco.mjtVisFlag.mjVIS_CONTACTFORCE] = False

render_every = 2

# If your environment is wrapped multiple times, adjust as needed:
base_env = brax_eval_env.env.env.env  # or brax_env.env.env.env
fps = 1.0 / base_env.dt / render_every
traj = render_trajectory[::render_every]
frames = raw_eval_env.render(
    traj,
    camera="track",
    height=480,
    width=640,
    scene_option=scene_option,
)

video_name = f"student_rollout.mp4"
media.write_video(f"{video_name}", frames, fps=fps)
print(f"Rollout video saved as '{video_name}'")
media.show_video(frames, fps=fps)
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 185.65it/s]
# Rollout video saved as 'student_rollout.mp4'
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="640" height="480" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# # Analyze the Learned Environment Latent $\hat{z}_t$ (optional)
# One thing you might be curious about is what the envirionment latent $z_t$ actually captures. One technique for doing this would be to grab the ActorCriticLatent policy that you trained, and pass in hand-made environment observations vectors to see how it affects $z_t$. Alternatively, you could also collect $z_t$ values while rolling out the policy in randomized environments. Since $z_t$ is likely > 2 dimensions, you may find it useful to visualize it using visualization / latent space projection techniques such as tSNE.

# %%
# Your Code Here

# %% [markdown]
# ## What to Turn In
#
# `#TODO(student):` Please zip the following files and turn them into the assignment on gradescope:
# 1. this `08_lab_student.ipynb` file. Please make sure to fill our your name and umich ID in the first cell
# 2. the `dagger.py` file
#
# Please ensure all cell outputs (videos, plots, etc) are in tact when you download the .ipynb file.
